# %% [markdown]
# ## Generated CSV Names
# - Uniqu customers csv = unique_customers_rfm.csv
# - the dataset which calculated rfm values =  df_rfm

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta

# %%
path = "./DataSources/before_analysis.csv"
df = pd.read_csv(path)

# %%
df['created_at'] = pd.to_datetime(df['created_at'])

df['month'] = df['created_at'].dt.to_period('M')

monthly_order_value = df.groupby('month')['order_value'].sum()
monthly_order_value
# Out:
# month
# 2023-03    108789.63
# 2023-04    154848.64
# 2023-05    175371.05
# 2023-06    168516.51
# 2023-07    157060.30
# 2023-08    164379.35
# 2023-09    181060.65
# 2023-10    149496.05
# 2023-11    169659.81
# 2023-12    106407.34
# 2024-01     72360.25
# 2024-02     47670.77
# Freq: M, Name: order_value, dtype: float64

# %%
# Plot the sum of 'order_value' by month
plt.figure(figsize=(10, 6))
bar_plot = monthly_sum.plot(kind='bar', color='skyblue')
plt.title('Total Order Value by Month')
plt.xlabel('Month')
plt.ylabel('Total Order Value')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Add value labels on top of each bar
for i, value in enumerate(monthly_sum):
    plt.text(i, value, f'{value:.2f}', ha='center', va='bottom')

plt.gca().set_xticklabels(monthly_sum.index.strftime('%b %Y'))


plt.tight_layout()
plt.show()

# %% [markdown]
# #### This are the columns which will be used in the Training Dataset.
# recency, frequency, total_spend_by_customer, walletShare by merchant, walletsharebycategory
