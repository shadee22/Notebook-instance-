# %%
print("hi")
# Out:
# hi

# %% [markdown]
# ## The issue is there rowss which is not empty string but the null value is there with the null

# %%
import pandas as pd

m1_transaction_report = pd.read_csv('./datasource/M1_Transaction Report.csv')

m1_transaction_report
# Out:
#                             Conversion ID Advertiser   Status  \
# 0        bb5e761027684e82b543e849303f04c9  Shopee SG  Pending
# 1      d0ad304720c748ad94634d3f1cb3e37d-1  Shopee SG  Pending
# 2      d9ebf3d492944f9286c30462de4d95ef-1  Shopee SG  Pending
# 3      118e364f81c440349265c1cab1da20df-1  Shopee SG  Pending
# 4      9193e3d670b042dbba3516c89084cc68-1  Shopee SG  Pending
# ...                                   ...        ...      ...
# 13092                                 NaN        NaN      NaN
# 13093                                 NaN        NaN      NaN
# 13094                                 NaN        NaN      NaN
# 13095                                 NaN        NaN      NaN
# 13096                                 NaN        NaN      NaN
#
#                            Order ID   Conversion Time        Click Time  \
# 0       2407192QGMUVTD_8824743777_1  19/07/2024 21:12  19/07/2024 21:06
# 1      240719158R58MW_24657216215_1  19/07/2024 06:13  19/07/2024 06:11
# ...

# %%
m1_transaction_report.shape
# Out:
# (13097, 16)

# %%
m1_transaction_report.isnull().sum()
# Out:
# Conversion ID                                                                       1235
# Advertiser                                                                          1234
# Status                                                                              1234
# Order ID                                                                            1234
# Conversion Time                                                                     1234
# Click Time                                                                          1236
# Currency                                                                            1234
# EUID                                                                                1293
# Estimate Order Value                                                                1234
# Estimate Optimise Cashback Value                                                    1242
# ...

# %%
m1_transaction_report[m1_transaction_report['Conversion ID'].notna()].tail(11)
# Out:
#                             Conversion ID         Advertiser    Status  \
# 11852    4001bc6ebe3040c8b37dd1c38aab9a90                KFC  Approved
# 11853  5f441a1316d348faaf1a90b238eeca32-1          Zalora SG  Approved
# 11854  f1b831c3b9244928abc842d763870272-1          Zalora SG  Approved
# 11855  72da5e4a02b942969d714b396770c0a1-1             PatPat  Approved
# 11856  9a7f2318994c4cc29b81c634813b3ad6-1  Watsons Singapore  Approved
# 11857  b566bafeeb2544fb8e33d45c9e823503-1  Watsons Singapore  Approved
# 11858  e7fc921a109d47bfb7425b8a3cf8b7a4-1  Watsons Singapore  Approved
# 11859  de54d92e124d4b3296ee4ba8e52c457a-1  Watsons Singapore  Approved
# 11860  3a2694a088af4072a730f06b2571913c-1  Watsons Singapore  Approved
# 11861  17c74deaa4564c5a94e92e5084498231-1  Watsons Singapore  Approved
# 11862  62e5fda4cafe4dfeb7a223f10ed34cf8-1  Watsons Singapore  Approved
#
#                                                 Order ID   Conversion Time  \
# ...

# %%
m1_transaction_report.tail(1235).isna().sum()
# Out:
# Conversion ID                                                                      1234
# Advertiser                                                                         1234
# Status                                                                             1234
# Order ID                                                                           1234
# Conversion Time                                                                    1234
# Click Time                                                                         1234
# Currency                                                                           1234
# EUID                                                                               1234
# Estimate Order Value                                                               1234
# Estimate Optimise Cashback Value                                                   1234
# Cashback % or Amount                                                               1234
# ...

# %%
import matplotlib.pyplot as plt

na_values = m1_transaction_report.tail(1235).isna().sum()
na_values_diff = na_values.diff()
na_values_diff.plot(kind='bar')
plt.title('Difference in Missing Values in the Last 1235 Rows')
plt.show()

# %%
m1_transaction_report.tail(1235).notna().sum()
# Out:
# Conversion ID                                                                      1
# Advertiser                                                                         1
# Status                                                                             1
# Order ID                                                                           1
# Conversion Time                                                                    1
# Click Time                                                                         1
# Currency                                                                           1
# EUID                                                                               1
# Estimate Order Value                                                               1
# Estimate Optimise Cashback Value                                                   1
# Cashback % or Amount                                                               1
# ...

# %%
m1_transaction_report[m1_transaction_report.notna().all(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Conversion ID, Advertiser, Status, Order ID, Conversion Time, Click Time, Currency, EUID, Estimate Order Value, Estimate Optimise Cashback Value, Cashback % or Amount, Estimate M1 Cashback Value, Estimate Cashback Value
# (Exclude GST),  , Settlement Date, Partner Approved but payment not received. But pulseid have done the settlement]
# Index: []
